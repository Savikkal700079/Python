# %%
name = "Aarish"
age = 8
print("Name=%s and Age=%d"%(name,age))
print("Name =%s and Age=%d"%("Anika",6))
# Out:
# Name=Aarish and Age=8
# Name =Anika and Age=6

# %%
#Returns True if string has atleast 1 character and every character is either a number or an alphabet and False otherwise.

message="JamesBond007"
print(message.isalnum())
# Out:
# True

# %%
message="JamesBond007"
print(message.isalpha())
# Out:
# False

# %%
message="007"
print(message.isdigit())
# Out:
# True

# %%
message="Hello"
print(message.islower())
# Out:
# False

# %%
message="   "
print(message.isspace())
# Out:
# True

# %%
message="HELLO"
print(message.isupper())
# Out:
# True

# %%
str="Hello"
print(len(str))
# Out:
# 5

# %%
#ljust(width[,fillchar])
str="Hello"
print(str.ljust(10,'*'))
# Out:
# Hello*****

# %%
str='Hello'
print(str.rjust(10,"*"))
# Out:
# *****Hello

# %%
str="Hello"
print(str.lower())
# Out:
# hello

# %%
str="Hello"
print(str.upper())
# Out:
# HELLO

# %%
str="   Hello"
print(str.lstrip())
# Out:
# Hello

# %%
str="         Hello   "
print(str.rstrip())
# Out:
#          Hello

# %%
str="            hello        "
print(str.strip())
# Out:
# hello

# %%
str="hello friendz"
print(max(str))
# Out:
# z

# %%
str="helloDfriendz"
print(min(str))
# Out:
# D

# %%
str="hellohellohello"
print(str.replace("he","FO"))
# Out:
# FOlloFOlloFOllo

# %%
str="The world is Beautiful"
print(str.swapcase())
# Out:
# tHE WORLD IS bEAUTIFUL
